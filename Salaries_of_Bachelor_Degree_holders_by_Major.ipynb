# %% [markdown]
# <a href="https://colab.research.google.com/github/fherdy/Salaries-of-Bachelor-Degree-Holders-by-Major/blob/main/Salaries_of_Bachelor_Degree_holders_by_Major.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('salaries_by_college_major.csv')
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df = df.dropna()

# %%
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
clean_df['Starting Median Salary']
# Out:
# 0     46000.0
# 1     57700.0
# 2     42600.0
# 3     36800.0
# 4     41600.0
# 5     35800.0
# 6     38800.0
# 7     43000.0
# 8     63200.0
# 9     42600.0
# 10    53900.0
# 11    38100.0
# 12    61400.0
# 13    55900.0
# 14    53700.0
# 15    35000.0
# 16    35900.0
# 17    50100.0
# 18    34900.0
# 19    60900.0
# 20    38000.0
# 21    37900.0
# 22    47900.0
# 23    39100.0
# 24    41200.0
# 25    43500.0
# 26    35700.0
# 27    38800.0
# 28    39200.0
# 29    37800.0
# 30    57700.0
# 31    49100.0
# 32    36100.0
# 33    40900.0
# 34    35600.0
# 35    49200.0
# 36    40800.0
# 37    45400.0
# 38    57900.0
# 39    35900.0
# 40    54200.0
# 41    39900.0
# 42    39900.0
# 43    74300.0
# 44    50300.0
# 45    40800.0
# 46    35900.0
# 47    34100.0
# 48    36500.0
# 49    34000.0
# Name: Starting Median Salary, dtype: float64

# %%
clean_df['Starting Median Salary'].max()
# Out:
# 74300.0

# %%
max_median_sal = clean_df['Starting Median Salary'].max()
clean_df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
clean_df['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
clean_df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %%
#College major with the highest mid-career salary
max_mid_career_sal_index = clean_df['Mid-Career Median Salary'].idxmax()
clean_df['Mid-Career Median Salary'].max
clean_df['Undergraduate Major'][max_mid_career_sal_index]
# Out:
# 'Chemical Engineering'

# %%
clean_df['Mid-Career Median Salary'].max()
# Out:
# 107000.0

# %%
#College major with the lowest starting salary
min_start_career_sal_index = clean_df['Starting Median Salary'].idxmin()
clean_df['Undergraduate Major'][min_start_career_sal_index]
# Out:
# 'Spanish'

# %%
clean_df['Starting Median Salary'].min()
# Out:
# 34000.0

# %%
#College major with the lowest mid-career salary
min_mid_career_sal_index = clean_df['Mid-Career Median Salary'].idxmin()
clean_df['Undergraduate Major'][min_mid_career_sal_index]
# Out:
# 'Education'

# %%
clean_df['Mid-Career Median Salary'].min()
# Out:
# 52000.0

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
clean_df.insert(6,"Spread (90th P - 10th P)", spread_col)

# %%
clean_df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group  Spread (90th P - 10th P)
# 0  Business                  109800.0
# ...

# %%
low_risk = clean_df.sort_values('Spread (90th P - 10th P)')
low_risk[['Undergraduate Major', 'Spread (90th P - 10th P)']].head()
# Out:
#            Undergraduate Major  Spread (90th P - 10th P)
# 40                     Nursing                   50700.0
# 43         Physician Assistant                   57600.0
# 41                   Nutrition                   65300.0
# 49                     Spanish                   65400.0
# 27  Health Care Administration                   66400.0

# %%
clean_df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
clean_df.sort_values('Starting Median Salary')
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 49                               Spanish                 34000.0
# 47                              Religion                 34100.0
# 18                             Education                 34900.0
# 15                      Criminal Justice                 35000.0
# 34                            Journalism                 35600.0
# 26                        Graphic Design                 35700.0
# 5                            Art History                 35800.0
# 16                                 Drama                 35900.0
# 46                            Psychology                 35900.0
# 39                                 Music                 35900.0
# 32                       Interior Design                 36100.0
# 48                             Sociology                 36500.0
# 3                           Anthropology                 36800.0
# ...

# %%
#Degrees with the highest potential (To 5 degrees with the highest values in the 90th Percentile)
top_five  = clean_df.sort_values(by='Mid-Career 90th Percentile Salary',ascending=False).head()

# %%
top_five
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17             Economics                 50100.0                   98600.0
# 22               Finance                 47900.0                   88300.0
# 8   Chemical Engineering                 63200.0                  107000.0
# 37                  Math                 45400.0                   92400.0
# 44               Physics                 50300.0                   97300.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 17                            50600.0                           210000.0
# 22                            47200.0                           195000.0
# 8                             71900.0                           194000.0
# 37                            45200.0                           183000.0
# 44                            56000.0                           178000.0
#
#        Group  Spread (90th P - 10th P)
# ...

# %%
#Degrees with the largest difference between high and low earners
highest_spread = clean_df.sort_values(by='Spread (90th P - 10th P)',ascending=False).head()

# %%
highest_spread
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17           Economics                 50100.0                   98600.0
# 22             Finance                 47900.0                   88300.0
# 37                Math                 45400.0                   92400.0
# 36           Marketing                 40800.0                   79600.0
# 42          Philosophy                 39900.0                   81200.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 17                            50600.0                           210000.0
# 22                            47200.0                           195000.0
# 37                            45200.0                           183000.0
# 36                            42100.0                           175000.0
# 42                            35500.0                           168000.0
#
#        Group  Spread (90th P - 10th P)
# 17  Business                  159400.0
# ...

# %%
#Degrees with the largest paying at mid level
highest_mid_career = clean_df.sort_values(by='Mid-Career Median Salary', ascending=False)
highest_mid_career[['Undergraduate Major','Mid-Career Median Salary']].head()
# Out:
#        Undergraduate Major  Mid-Career Median Salary
# 8     Chemical Engineering                  107000.0
# 12    Computer Engineering                  105000.0
# 19  Electrical Engineering                  103000.0
# 1    Aerospace Engineering                  101000.0
# 17               Economics                   98600.0

# %%
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Starting Median Salary  \
# Group
# Business                   12                      12
# HASS                       22                      22
# STEM                       16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary  Spread (90th P - 10th P)
# Group
# Business                                 12                        12
# HASS                                     22                        22
# STEM                                     16                        16

# %%
grouped_clean_df = clean_df.groupby('Group')
grouped_clean_df.mean()
# Out:
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business            44633.333333              75083.333333
# HASS                37186.363636              62968.181818
# STEM                53862.500000              90812.500000
#
#           Mid-Career 10th Percentile Salary  \
# Group
# Business                       43566.666667
# HASS                           34145.454545
# STEM                           56025.000000
#
#           Mid-Career 90th Percentile Salary  Spread (90th P - 10th P)
# Group
# Business                      147525.000000             103958.333333
# HASS                          129363.636364              95218.181818
# STEM                          157625.000000             101600.000000

# %%
pd.options.display.float_format = '{:,.2f}'.format 
grouped_clean_df.mean()
# Out:
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business               44,633.33                 75,083.33
# HASS                   37,186.36                 62,968.18
# STEM                   53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  \
# Group
# Business                          43,566.67
# HASS                              34,145.45
# STEM                              56,025.00
#
#           Mid-Career 90th Percentile Salary  Spread (90th P - 10th P)
# Group
# Business                         147,525.00                103,958.33
# HASS                             129,363.64                 95,218.18
# STEM                             157,625.00                101,600.00
